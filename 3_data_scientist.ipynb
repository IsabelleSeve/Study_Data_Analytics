# %% [markdown]
# Notebook 3 — Ciência de Dados
# 03_machine_learning.ipynb
#
# Esse notebook é totalmente voltado para modelagem.
#
# Aqui você atua como Data Scientist.
#
# Primeiro passo
#
# Ler parquet:
#
# df_ml = spark.read.parquet(
#     "data/processed/home_credit_featured.parquet"
# )
# Temas que entram aqui
# 6. Preparação dos Dados para Modelagem
#
# Inclua:
#
# X e y;
# encoding;
# scaler;
# VectorAssembler;
# split treino/teste;
# balanceamento.
# 7. Modelagem
#
# Inclua:
#
# Logistic Regression;
# Decision Tree;
# Random Forest;
# pipelines;
# tuning.
# 8. Avaliação dos Modelos
#
# Inclua:
#
# Accuracy;
# Precision;
# Recall;
# F1;
# ROC-AUC;
# comparação de modelos.
# 9. Pipeline Final
#
# Inclua:
#
# pipeline Spark ML;
# persistência do modelo;
# teste com novos dados.
# Resultado do Notebook 3
